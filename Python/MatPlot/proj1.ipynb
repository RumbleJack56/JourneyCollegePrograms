# %% [markdown]
# ### Imports
# This is my learning journey of *[Matplotlib](https://matplotlib.org/)* and *[Seaborne](https://seaborn.pydata.org/)*
# So those will be imported

# %%
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ### Code

# %%
x_vals = [1,2,4,5,6,7,12,19]
y_vals = np.round(30*np.random.random(8))
plt.plot(x_vals,y_vals)
